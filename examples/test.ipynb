# %%
# !python fit_models_huga.py --pre "tcn" --fit_tcn --dataset "huga" --n_samples 5 --n_labels "100;250" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"
# Out:
# here
# ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# sess to keep ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/huga
#     expt_ids: ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
#     expt_ids_test: ['sess_06', 'sess_08', 'sess_11', 'sess_13', 'sess_17']
#     expt_ids_to_keep: sess_05;sess_07;sess_09;sess_12;sess_14
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'walking', 'running', 'going_up', 'going_down', 'sitting', 'sitting_down', 'standing_up', 'standing']
#     n_aug_classes: 0
#     n_observed_classes: 9
#     output_size: 9
#     results_dir: /home/bsb2144/daart/results_daart/huga
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end: 125
#     anneal_end_y: 125
#     anneal_start: 25
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
# !python fit_models_huga.py --pre "tcn" --fit_tcn --dataset "huga" --n_samples 5 --n_labels "500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"
# Out:
# here
# ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# sess to keep ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/huga
#     expt_ids: ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
#     expt_ids_test: ['sess_06', 'sess_08', 'sess_11', 'sess_13', 'sess_17']
#     expt_ids_to_keep: sess_05;sess_07;sess_09;sess_12;sess_14
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'walking', 'running', 'going_up', 'going_down', 'sitting', 'sitting_down', 'standing_up', 'standing']
#     n_aug_classes: 0
#     n_observed_classes: 9
#     output_size: 9
#     results_dir: /home/bsb2144/daart/results_daart/huga
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end: 125
#     anneal_end_y: 125
#     anneal_start: 25
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
# !python fit_models_huga.py --pre "rsl" --fit_rsldsm --linear --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"
# Out:
# here
# ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# sess to keep ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/huga
#     expt_ids: ['sess_05', 'sess_07', 'sess_09', 'sess_12', 'sess_14']
#     expt_ids_test: ['sess_06', 'sess_08', 'sess_11', 'sess_13', 'sess_17']
#     expt_ids_to_keep: sess_05;sess_07;sess_09;sess_12;sess_14
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'walking', 'running', 'going_up', 'going_down', 'sitting', 'sitting_down', 'standing_up', 'standing']
#     n_aug_classes: 0
#     n_observed_classes: 9
#     output_size: 9
#     results_dir: /home/bsb2144/daart/results_daart/huga
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end: 125
#     anneal_end_y: 125
#     anneal_start: 25
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
# !python fit_models_huga.py --pre "rsln" --fit_rsldsm --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"

# %%
# !python fit_models_huga.py --pre "gm" --fit_gmdgm --temporal --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"

# %%
# !python fit_models_huga.py --pre "gmnt" --fit_gmdgm --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"
