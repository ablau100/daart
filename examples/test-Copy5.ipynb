# %%
# tree results

# xgb
#!python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# rf
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# rf
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# huga trees
# tree results

# xgb
# !python fit_models_huga.py --pre "xgb" --fit_xgb --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"

# rf
# !python fit_models_huga.py --pre "rf" --fit_rf --dataset "huga" --n_samples 5 --n_labels "100;250;500;1000" --data "/home/bsb2144/daart_utils/configs/data_huga.yaml" --model "/home/bsb2144/daart_utils/configs/model_huga.yaml" --train "/home/bsb2144/daart_utils/configs/train_huga.yaml"

# %%
# oft - m/pv
# tcn
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
#rsl
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# rsln
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# gmdgm - tcn
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
#gmdgm - nt
# !python fit_models_subsample_loop.py --pre "gmnt" --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "gmnt" --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft3.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# sets of 5s
# rsl
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit

# %%
# rsln
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit

# %%
# gmdgm-tcn
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
# ...

# %%
# gmdgm-nt
# !python fit_models_subsample_loop.py --pre "gmnt"  --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "gmnt"  --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# tcn
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft3.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft4.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft4.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-sturman-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...
