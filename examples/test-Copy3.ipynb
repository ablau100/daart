# %%
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "fly-5" --n_samples 5 --fracs ".8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_fly-5b.yaml" --model "/home/bsb2144/daart_utils/configs/model_fly.yaml" --train "/home/bsb2144/daart_utils/configs/train_fly.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/fly-5
#     expt_ids: ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
#     expt_ids_test: ['2019_06_26_fly2', '2019_08_14_fly1', '2019_08_20_fly3', '2019_10_14_fly2', '2019_10_21_fly1']
#     expt_ids_to_keep: 2019_08_07_fly2;2019_08_08_fly1;2019_08_20_fly2;2019_10_14_fly3
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'walk', 'front_groom', 'back_groom', 'abdomen-move']
#     n_aug_classes: 0
#     n_observed_classes: 6
#     output_size: 6
#     results_dir: /home/bsb2144/daart/results_daart/fly-5
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
# ...
